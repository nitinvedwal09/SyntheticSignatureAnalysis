# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import os
import glob
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import math
import time
import statistics
import random
pie = 3.14159265359

# %%
def features(path):
    with open(f"{path}") as f:
        data = np.loadtxt(f)
        # shifting points to the origin
        xmin = data[0][0]
        ymin = data[0][1]
        xmax = data[0][0]
        ymax = data[0][1]
        for i in range(len(data)):
            xmin = min(xmin, data[i][0])
            ymin = min(ymin, data[i][1])
            xmax = max(xmax, data[i][0])
            ymax = max(ymax, data[i][1])
        # here totalpoints are the points with pendowns only
        totalpoints = 0
        for i in range(len(data)):
            if (data[i][3]):
                totalpoints += 1
        # ---------------------------section 1 -----------------------------------------------------
        # x y and pressure series
        # x , y and pressure series,     x mean , y mean and pressure mean ,     sd x , sd y sd pressure
        x = []
        y = []
        pressure = []
        meanx = 0
        meany = 0
        meanpressure = 0
        stdx = 0
        stdy = 0
        stdpressure = 0

        # time series for section 2
        timeseries = []

        for i in range(len(data)):
            if (data[i][3]):
                x.append((data[i][0]-xmin))
                y.append((data[i][1]-ymin))
                timeseries.append(data[i][2])
                pressure.append(data[i][4])

        meanx = sum(x)/totalpoints
        meany = sum(y)/totalpoints
        meanpressure = sum(pressure)/totalpoints
        # print("mean x is"+str(meanx))
        # print("mean y is"+str(meany))
        # print("mean pressure is"+str(meanpressure))

        stdsumx = 0  # (x^2-u)
        stdsumy = 0
        stdsumpressure = 0

        for i in range(len(x)):
            stdsumx += pow((x[i]-meanx), 2)
            stdsumy += pow((y[i]-meany), 2)
            stdsumpressure += pow((pressure[i]-meanpressure), 2)

        stdx = math.sqrt(stdsumx/totalpoints)
        stdy = math.sqrt(stdsumy/totalpoints)
        stdpressure = math.sqrt(stdsumpressure/totalpoints)

        # print("std x is "+str(stdx))
        # print("std y is"+str(stdy))
        # print("std pressure is"+str(stdpressure))
        # print(timeseries)

        # ------------------------------section 2------------------------------------------------------
        # radial distance and theta series
        # radialdist=d
        d = []
        theta = []

        meand = 0
        meantheta = 0

        stdd = 0
        stdtheta = 0

        for i in range(len(data)):
            if (data[i][3]):
                d.append(
                    math.sqrt(pow(data[i][0]-xmin, 2)+pow(data[i][1]-ymin, 2)))
                if (data[i][0]-xmin == 0):
                    theta.append(pie/2)
                else:
                    theta.append(
                        math.atan((data[i][1]-ymin)/(data[i][0]-xmin)))

        meand = sum(d)/totalpoints
        meantheta = sum(theta)/totalpoints

        # print("mean d is"+str(meand))
        # print("mean theta is"+str(meantheta))

        mediand = statistics.median(d)
        mediantheta = statistics.median(theta)

        # print("meadin of d is"+str(mediand))
        # print("median of theta is"+str(mediantheta))

        stdsumd = 0
        stdsumtheta = 0
        for i in range(len(d)):
            stdsumd += pow(d[i]-meand, 2)
            stdsumtheta += pow(theta[i]-meantheta, 2)

        stdd = math.sqrt(stdsumd/totalpoints)
        stdtheta = math.sqrt(stdsumtheta/totalpoints)

        # print("std d is"+str(stdd))
        # print("std theta is"+str(stdtheta))
        # ------------------------section 5----------------------------------------------
        #  making skewness and kurtosis
        skewnesssumx = 0
        skewnesssumy = 0
        kurtosissumx = 0
        kurtosissumy = 0
        for i in range(len(x)):
            skewnesssumx += pow((x[i]-meanx), 3)
            skewnesssumy += pow((y[i]-meany), 3)
            kurtosissumx += pow((x[i]-meanx), 4)
            kurtosissumy += pow((y[i]-meany), 4)
        skewnessx = skewnesssumx/((totalpoints-1)*pow(stdx, 3))
        skewnessy = skewnesssumy/((totalpoints-1)*pow(stdy, 3))
        kurtosisx = kurtosissumx/((totalpoints-1)*pow(stdx, 3))
        kurtosisy = kurtosissumy/((totalpoints-1)*pow(stdx, 3))

        # ------------------------section 3----------------------------------------------
        # velocity acceleration angular velocity
        tend = max(timeseries)
        tstart = min(timeseries)

        velocity = []
        acceleration = []
        angvelocity = []

        for i in range(len(x)-1):
            temp = (math.sqrt(pow(x[i+1]-x[i], 2) +
                    pow(y[i+1]-y[i], 2)))*(tend-tstart)
            velocity.append(temp/(timeseries[i+1]-timeseries[i]))
            if (x[i+1] == 0 or x[i] == 0):
                if (x[i+1] == 0 and x[i] == 0):
                    temp1 = 0
                elif (x[i+1] == 0 and x[i] != 0):
                    temp1 = (abs(pie/2 -
                                 math.atan(y[i]/x[i])))*(tend-tstart)
                elif (x[i+1] != 0 and x[i] == 0):
                    temp1 = (abs(math.atan(y[i+1]/x[i+1]) -
                                 pie/2))*(tend-tstart)

            else:
                temp1 = (abs(math.atan(y[i+1]/x[i+1]) -
                             math.atan(y[i]/x[i])))*(tend-tstart)
            angvelocity.append(temp1/(timeseries[i+1]-timeseries[i]))

        for i in range(len(velocity)-1):
            temp = (abs(velocity[i+1]-velocity[i]))*(tend-tstart)
            acceleration.append(temp/(timeseries[i+1]-timeseries[i]))
        avgvelocity = sum(velocity)/len(velocity)
        avgacceleration = sum(acceleration)/len(acceleration)
        avgangvelocity = sum(angvelocity)/len(angvelocity)
        # -------------------------section 4-----------------------------------------------
        # numbers of penups and down, and ratio of signature
        pencount = 0
        for i in range(len(data)-1):
            if (data[i+1][3] != data[i][3]):
                pencount += 1
        ratio = (ymax-ymin)/(xmax-xmin)

        # --------------------------making features vector----------------------------------
        features = []
        features.append(meanx)
        features.append(meany)
        features.append(meanpressure)
        features.append(stdx)
        features.append(stdy)
        features.append(stdpressure)
        features.append(meand)
        features.append(meantheta)
        features.append(mediand)
        features.append(mediantheta)
        features.append(stdd)
        features.append(stdtheta)
        features.append(skewnessx)
        features.append(skewnessy)
        features.append(kurtosisx)
        features.append(kurtosisy)
        features.append(avgvelocity)
        features.append(avgacceleration)
        features.append(avgangvelocity)
        features.append(pencount)
        features.append(ratio)
    return features

# %%
file = "/content/drive/My Drive/UGP23"
if not (os.path.exists('/content/drive/My Drive/UGP23/Features')):
    os.mkdir('/content/drive/My Drive/UGP23/Features')
    print('New folder "Features" created')
if not (os.path.exists('/content/drive/My Drive/UGP23/Features/Training')):
    os.mkdir('/content/drive/My Drive/UGP23/Features/Training')
    print('New folder "Features/Training" created')
if not (os.path.exists('/content/drive/My Drive/UGP23/Features/Testing')):
    os.mkdir('/content/drive/My Drive/UGP23/Features/Testing')
    print('New folder "Features/Training" created')
data = "/content/drive/My Drive/UGP23/DS1_Modification_TimeFunctions"
traindata = "/content/drive/My Drive/UGP23/Features/Training"
# /content/drive/My Drive/UGP23/DS1_Modification_TimeFunctions
# Out:
# New folder "Features/Training" created
# New folder "Features/Training" created

# %%
# Define the path to the folder containing all the data folders
traindata = "/content/drive/My Drive/UGP23/Features/Training"
data_folder_path = "/content/drive/My Drive/UGP23/DS1_Modification_TimeFunctions"

# Step 1: Get a list of all folder IDs
folder_ids = [f"usuario1{i:03}" for i in range(1, 351)]

# Step 2: Create a new CSV file for each folder ID
# Training
for folder_id in folder_ids:
    csv_file_path = os.path.join(traindata, f"Training{folder_id[-4:]}.csv")
    with open(csv_file_path, "w") as f:
        print("Creating Training csv file for usuario"+str(folder_id[-4:]))
        f.write(
            'meanx,meany,meanpressure,stdx,stdy,stdpressure,meand,meanthets,mediand,mediantheta,stdd,stdtheta,skewnessx,skewnessy,kurtosisx,kurtosisy,avgvelocity,avgacceleration,avgangvelocity,pencount,ratio,output\n')
        # Step 3: Extract data from the 15 text files within the current folder
        for i in range(1, 21):
            text_file_path = os.path.join(
                data_folder_path, folder_id, f"u{folder_id[-4:]}_sg{i}.txt")
            with open(text_file_path, "r") as tf:
                data = tf.read()
                # Write the text data to the current row of the CSV file
                feature = features(path=text_file_path)
                f.write(','.join(map(str, feature))+',1\n')

        # Step 4: Extract data from the first text file of each of the other 349 folders
        randomfolder_ids = random.sample(folder_ids, k=50)
        for other_folder_id in randomfolder_ids:
            if other_folder_id != folder_id:
                other_text_file_path = os.path.join(
                    data_folder_path, other_folder_id, f"u{other_folder_id[-4:]}_sg1.txt")
                with open(other_text_file_path, "r") as otf:
                    other_text_data = otf.read()
                    # Write the other text data to the current row of the CSV file
                    feature = features(path=other_text_file_path)
                    f.write(','.join(map(str, feature))+',0\n')

# Testing
testdata = "/content/drive/My Drive/UGP23/Features/Testing"
for folder_id in folder_ids:
    csv_file_path = os.path.join(testdata, f"Testing{folder_id[-4:]}.csv")
    with open(csv_file_path, "w") as f:
        print("Creating Testing csv file for usuario"+str(folder_id[-4:]))
        f.write(
            'meanx,meany,meanpressure,stdx,stdy,stdpressure,meand,meanthets,mediand,mediantheta,stdd,stdtheta,skewnessx,skewnessy,kurtosisx,kurtosisy,avgvelocity,avgacceleration,avgangvelocity,pencount,ratio,output\n')
        # Step 3: Extract data from the 15 text files within the current folder
        for i in range(21, 26):
            text_file_path = os.path.join(
                data_folder_path, folder_id, f"u{folder_id[-4:]}_sg{i}.txt")
            with open(text_file_path, "r") as tf:
                data = tf.read()
                # Write the text data to the current row of the CSV file
                feature = features(path=text_file_path)
                f.write(','.join(map(str, feature))+',1\n')

        # Step 4: Extract data from the first text file of each of the other 349 folders
        randomfolder_ids = random.sample(folder_ids, k=15)
        for other_folder_id in randomfolder_ids:
            if other_folder_id != folder_id:
                other_text_file_path = os.path.join(
                    data_folder_path, other_folder_id, f"u{other_folder_id[-4:]}_sg2.txt")
                with open(other_text_file_path, "r") as otf:
                    other_text_data = otf.read()
                    # Write the other text data to the current row of the CSV file
                    feature = features(path=other_text_file_path)
                    f.write(','.join(map(str, feature))+',0\n')
# Out:
# Creating Training csv file for usuario1001
# Creating Training csv file for usuario1002
# Creating Training csv file for usuario1003
# Creating Training csv file for usuario1004
# Creating Training csv file for usuario1005
# Creating Training csv file for usuario1006
# Creating Training csv file for usuario1007
# Creating Training csv file for usuario1008
# Creating Training csv file for usuario1009
# Creating Training csv file for usuario1010
# Creating Training csv file for usuario1011
# Creating Training csv file for usuario1012
# Creating Training csv file for usuario1013
# Creating Training csv file for usuario1014
# Creating Training csv file for usuario1015
# Creating Training csv file for usuario1016
# Creating Training csv file for usuario1017
# Creating Training csv file for usuario1018
# Creating Training csv file for usuario1019
# Creating Training csv file for usuario1020
# Creating Training csv file for usuario1021
# Creating Training csv file for usuario1022
# Creating Training csv file for usuario1023
# Creating Training csv file for usuario1024
# Creating Training csv file for usuario1025
# Creating Training csv file for usuario1026
# Creating Training csv file for usuario1027
# Creating Training csv file for usuario1028
# Creating Training csv file for usuario1029
# Creating Training csv file for usuario1030
# Creating Training csv file for usuario1031
# Creating Training csv file for usuario1032
# Creating Training csv file for usuario1033
# Creating Training csv file for usuario1034
# Creating Training csv file for usuario1035
# Creating Training csv file for usuario1036
# Creating Training csv file for usuario1037
# Creating Training csv file for usuario1038
# Creating Training csv file for usuario1039
# Creating Training csv file for usuario1040
# Creating Training csv file for usuario1041
# Creating Training csv file for usuario1042
# Creating Training csv file for usuario1043
# Creating Training csv file for usuario1044
# Creating Training csv file for usuario1045
# Creating Training csv file for usuario1046
# Creating Training csv file for usuario1047
# Creating Training csv file for usuario1048
# Creating Training csv file for usuario1049
# Creating Training csv file for usuario1050
# Creating Training csv file for usuario1051
# Creating Training csv file for usuario1052
# Creating Training csv file for usuario1053
# Creating Training csv file for usuario1054
# Creating Training csv file for usuario1055
# Creating Training csv file for usuario1056
# Creating Training csv file for usuario1057
# Creating Training csv file for usuario1058
# Creating Training csv file for usuario1059
# Creating Training csv file for usuario1060
# Creating Training csv file for usuario1061
# Creating Training csv file for usuario1062
# Creating Training csv file for usuario1063
# Creating Training csv file for usuario1064
# Creating Training csv file for usuario1065
# Creating Training csv file for usuario1066
# Creating Training csv file for usuario1067
# Creating Training csv file for usuario1068
# Creating Training csv file for usuario1069
# Creating Training csv file for usuario1070
# Creating Training csv file for usuario1071
# Creating Training csv file for usuario1072
# Creating Training csv file for usuario1073
# Creating Training csv file for usuario1074
# Creating Training csv file for usuario1075
# Creating Training csv file for usuario1170
# Creating Training csv file for usuario1171
# Creating Training csv file for usuario1172
# Creating Training csv file for usuario1173
# Creating Training csv file for usuario1174
# Creating Training csv file for usuario1175
# Creating Training csv file for usuario1176
# Creating Training csv file for usuario1177
# Creating Training csv file for usuario1178
# Creating Training csv file for usuario1179
# Creating Training csv file for usuario1180
# Creating Training csv file for usuario1181
# Creating Training csv file for usuario1182
# Creating Training csv file for usuario1183
# Creating Training csv file for usuario1184
# Creating Training csv file for usuario1185
# Creating Training csv file for usuario1186
# Creating Training csv file for usuario1187
# Creating Training csv file for usuario1188
# Creating Training csv file for usuario1189
# Creating Training csv file for usuario1190
# Creating Training csv file for usuario1191
# Creating Training csv file for usuario1192
# Creating Training csv file for usuario1193
# Creating Training csv file for usuario1194
# Creating Training csv file for usuario1195
# Creating Training csv file for usuario1196
# Creating Training csv file for usuario1197
# Creating Training csv file for usuario1198
# Creating Training csv file for usuario1199
# Creating Training csv file for usuario1200
# Creating Training csv file for usuario1201
# Creating Training csv file for usuario1202
# Creating Training csv file for usuario1203
# Creating Training csv file for usuario1204
# Creating Training csv file for usuario1205
# Creating Training csv file for usuario1206
# Creating Training csv file for usuario1207
# Creating Training csv file for usuario1208
# Creating Training csv file for usuario1209
# Creating Training csv file for usuario1210
# Creating Training csv file for usuario1211
# Creating Training csv file for usuario1212
# Creating Training csv file for usuario1213
# Creating Training csv file for usuario1214
# Creating Training csv file for usuario1215
# Creating Training csv file for usuario1216
# Creating Training csv file for usuario1217
# Creating Training csv file for usuario1218
# Creating Training csv file for usuario1219
# Creating Training csv file for usuario1220
# Creating Training csv file for usuario1221
# Creating Training csv file for usuario1222
# Creating Training csv file for usuario1223
# Creating Training csv file for usuario1224
# Creating Training csv file for usuario1225
# Creating Training csv file for usuario1226
# Creating Training csv file for usuario1227
# Creating Training csv file for usuario1228
# Creating Training csv file for usuario1229
# Creating Training csv file for usuario1230
# Creating Training csv file for usuario1231
# Creating Training csv file for usuario1232
# Creating Training csv file for usuario1233
# Creating Training csv file for usuario1234
# Creating Training csv file for usuario1235
# Creating Training csv file for usuario1236
# Creating Training csv file for usuario1237
# Creating Training csv file for usuario1238
# Creating Training csv file for usuario1239
# Creating Training csv file for usuario1240
# Creating Training csv file for usuario1241
# Creating Training csv file for usuario1242
# Creating Training csv file for usuario1243
# Creating Training csv file for usuario1244
# Creating Training csv file for usuario1245
# Creating Training csv file for usuario1246
# Creating Training csv file for usuario1247
# Creating Training csv file for usuario1248
# Creating Training csv file for usuario1249
# Creating Training csv file for usuario1250
# Creating Training csv file for usuario1251
# Creating Training csv file for usuario1252
# Creating Training csv file for usuario1253
# Creating Training csv file for usuario1254
# Creating Training csv file for usuario1255
# Creating Training csv file for usuario1256
# Creating Training csv file for usuario1257
# Creating Training csv file for usuario1258
# Creating Training csv file for usuario1259
# Creating Training csv file for usuario1260
# Creating Training csv file for usuario1261
